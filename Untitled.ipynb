# %%
import requests
from rich import print

cookies = {
    '_ga_WET17VWCJ3': 'GS1.1.1696792733.1.0.1696792733.0.0.0',
    '_ga': 'GA1.1.869041716.1696792734',
    '_pbjs_userid_consent_data': '3524755945110770',
    '_sharedid': 'f5aac7f4-572d-41d9-87f6-e23b8c7999a8',
    '_hjSessionUser_1667000': 'eyJpZCI6ImE4ODI1YjQ2LTA1YjgtNTA2OS1hMmQ5LTFkNGY4ZTg0OTg3YSIsImNyZWF0ZWQiOjE2OTY3OTI3MzQyMDUsImV4aXN0aW5nIjpmYWxzZX0=',
    '_hjFirstSeen': '1',
    '_hjIncludedInSessionSample_1667000': '1',
    '_hjSession_1667000': 'eyJpZCI6ImMwYWEwNDBiLTQ1YzMtNDkwZC04ZDkwLTE1ZmE2ZTM2ODE2NyIsImNyZWF0ZWQiOjE2OTY3OTI3MzQyMDUsImluU2FtcGxlIjp0cnVlLCJzZXNzaW9uaXplckJldGFFbmFibGVkIjp0cnVlfQ==',
    '_hjAbsoluteSessionInProgress': '0',
    'trc_cookie_storage': 'taboola%2520global%253Auser-id%3D841704af-203c-4db7-9250-a5a0c4e2af63-tuctc1c861f',
    'cto_bidid': 'JHaKXV9WcSUyQnVJa1pveiUyRndOcFB4bDZteVoyZkdENWtBYXQ2RmdyTWxYTkc2QzhldExNQktYOTklMkZOaEdhUlM2WmRhZVNOciUyRjVuajMxMnZYVG40OVBLbHRDWDk4UmFXRUZ5bUtuTkdSR0glMkJvdGRnZ0klM0Q',
    'cto_dna_bundle': 'e5zUJ18lMkJFWCUyRm1Ca2Rya05ab1hCRXJvejdWUmlxVjVycHR1aGlCWFNRSGJReEZQTUg2a0wlMkIxSDU0NTFjODJCd3N1MHhtQ01KdjJiaHN4MTYlMkZJbWpzY1MwSm53JTNEJTNE',
    'ccpa-notice-viewed-02': 'true',
    'cto_bundle': '',
}

headers = {
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Authorization': 'Basic dGVzdDp0ZXN0',
    'Cache-Control': 'no-cache',
    'Connection': 'keep-alive',
    'Content-Type': 'application/json',
    # 'Cookie': '_ga_WET17VWCJ3=GS1.1.1696792733.1.0.1696792733.0.0.0; _ga=GA1.1.869041716.1696792734; _pbjs_userid_consent_data=3524755945110770; _sharedid=f5aac7f4-572d-41d9-87f6-e23b8c7999a8; _hjSessionUser_1667000=eyJpZCI6ImE4ODI1YjQ2LTA1YjgtNTA2OS1hMmQ5LTFkNGY4ZTg0OTg3YSIsImNyZWF0ZWQiOjE2OTY3OTI3MzQyMDUsImV4aXN0aW5nIjpmYWxzZX0=; _hjFirstSeen=1; _hjIncludedInSessionSample_1667000=1; _hjSession_1667000=eyJpZCI6ImMwYWEwNDBiLTQ1YzMtNDkwZC04ZDkwLTE1ZmE2ZTM2ODE2NyIsImNyZWF0ZWQiOjE2OTY3OTI3MzQyMDUsImluU2FtcGxlIjp0cnVlLCJzZXNzaW9uaXplckJldGFFbmFibGVkIjp0cnVlfQ==; _hjAbsoluteSessionInProgress=0; trc_cookie_storage=taboola%2520global%253Auser-id%3D841704af-203c-4db7-9250-a5a0c4e2af63-tuctc1c861f; cto_bidid=JHaKXV9WcSUyQnVJa1pveiUyRndOcFB4bDZteVoyZkdENWtBYXQ2RmdyTWxYTkc2QzhldExNQktYOTklMkZOaEdhUlM2WmRhZVNOciUyRjVuajMxMnZYVG40OVBLbHRDWDk4UmFXRUZ5bUtuTkdSR0glMkJvdGRnZ0klM0Q; cto_dna_bundle=e5zUJ18lMkJFWCUyRm1Ca2Rya05ab1hCRXJvejdWUmlxVjVycHR1aGlCWFNRSGJReEZQTUg2a0wlMkIxSDU0NTFjODJCd3N1MHhtQ01KdjJiaHN4MTYlMkZJbWpzY1MwSm53JTNEJTNE; ccpa-notice-viewed-02=true; cto_bundle=',
    'Origin': 'https://www.ratemyprofessors.com',
    'Pragma': 'no-cache',
    'Referer': 'https://www.ratemyprofessors.com/search/professors?q=Werk',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36 Edg/117.0.2045.43',
    'sec-ch-ua': '"Microsoft Edge";v="117", "Not;A=Brand";v="8", "Chromium";v="117"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

json_data = {
    'query': 'query TeacherSearchResultsPageQuery(\n  $query: TeacherSearchQuery!\n  $schoolID: ID\n) {\n  search: newSearch {\n    ...TeacherSearchPagination_search_1ZLmLD\n  }\n  school: node(id: $schoolID) {\n    __typename\n    ... on School {\n      name\n    }\n    id\n  }\n}\n\nfragment TeacherSearchPagination_search_1ZLmLD on newSearch {\n  teachers(query: $query, first: 8, after: "") {\n    didFallback\n    edges {\n      cursor\n      node {\n        ...TeacherCard_teacher\n        id\n        __typename\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    resultCount\n    filters {\n      field\n      options {\n        value\n        id\n      }\n    }\n  }\n}\n\nfragment TeacherCard_teacher on Teacher {\n  id\n  legacyId\n  avgRating\n  numRatings\n  ...CardFeedback_teacher\n  ...CardSchool_teacher\n  ...CardName_teacher\n  ...TeacherBookmark_teacher\n}\n\nfragment CardFeedback_teacher on Teacher {\n  wouldTakeAgainPercent\n  avgDifficulty\n}\n\nfragment CardSchool_teacher on Teacher {\n  department\n  school {\n    name\n    id\n  }\n}\n\nfragment CardName_teacher on Teacher {\n  firstName\n  lastName\n}\n\nfragment TeacherBookmark_teacher on Teacher {\n  id\n  isSaved\n}\n',
    'variables': {
        'query': {
            'text': 'Werk',
            'schoolID': '',
            'fallback': True,
            'departmentID': None,
        },
        'schoolID': '',
    },
}

response = requests.post('https://www.ratemyprofessors.com/graphql', cookies=cookies, headers=headers, json=json_data)

# Note: json_data will not be serialized by requests
# exactly as it was in the original request.
#data = '{"query":"query TeacherSearchResultsPageQuery(\\n  $query: TeacherSearchQuery!\\n  $schoolID: ID\\n) {\\n  search: newSearch {\\n    ...TeacherSearchPagination_search_1ZLmLD\\n  }\\n  school: node(id: $schoolID) {\\n    __typename\\n    ... on School {\\n      name\\n    }\\n    id\\n  }\\n}\\n\\nfragment TeacherSearchPagination_search_1ZLmLD on newSearch {\\n  teachers(query: $query, first: 8, after: \\"\\") {\\n    didFallback\\n    edges {\\n      cursor\\n      node {\\n        ...TeacherCard_teacher\\n        id\\n        __typename\\n      }\\n    }\\n    pageInfo {\\n      hasNextPage\\n      endCursor\\n    }\\n    resultCount\\n    filters {\\n      field\\n      options {\\n        value\\n        id\\n      }\\n    }\\n  }\\n}\\n\\nfragment TeacherCard_teacher on Teacher {\\n  id\\n  legacyId\\n  avgRating\\n  numRatings\\n  ...CardFeedback_teacher\\n  ...CardSchool_teacher\\n  ...CardName_teacher\\n  ...TeacherBookmark_teacher\\n}\\n\\nfragment CardFeedback_teacher on Teacher {\\n  wouldTakeAgainPercent\\n  avgDifficulty\\n}\\n\\nfragment CardSchool_teacher on Teacher {\\n  department\\n  school {\\n    name\\n    id\\n  }\\n}\\n\\nfragment CardName_teacher on Teacher {\\n  firstName\\n  lastName\\n}\\n\\nfragment TeacherBookmark_teacher on Teacher {\\n  id\\n  isSaved\\n}\\n","variables":{"query":{"text":"Werk","schoolID":"","fallback":true,"departmentID":null},"schoolID":""}}'
#response = requests.post('https://www.ratemyprofessors.com/graphql', cookies=cookies, headers=headers, data=data)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'data': {'school': None,
#   'search': {'teachers': {'didFallback': False,
#     'edges': [{'cursor': 'YXJyYXljb25uZWN0aW9uOjA=',
#       'node': {'__typename': 'Teacher',
#        'avgDifficulty': 3,
#        'avgRating': 3,
#        'department': 'Psychology',
#        'firstName': 'Christine',
#        'id': 'VGVhY2hlci0xNzQzNjI1',
#        'isSaved': False,
#        'lastName': 'Werk',
#        'legacyId': 1743625,
#        'numRatings': 5,
#        'school': {'id': 'U2Nob29sLTE0MDc=', 'name': 'University of Alberta'},
#        'wouldTakeAgainPercent': -1}},
#      {'cursor': 'YXJyYXljb25uZWN0aW9uOjE=',
#       'node': {'__typename': 'Teacher',
#        'avgDifficulty': 3,
#        'avgRating': 4.2,
#        'department': 'Languages',
#        'firstName': 'Susanne',
#        'id': 'VGVhY2hlci01OTk0NzI=',
#        'isSaved': False,
#        'lastName': 'Werk',
#        'legacyId': 599472,
#        'numRatings': 22,
# ...

# %%
from bs4 import BeautifulSoup

# %%
import lxml.html
root = lxml.html.fromstring(res.text)
from rich import print


def get_xpath(e, xpath: str, one: bool = False, join_text = False):
    t = e.xpath(xpath)
    if one:
        return t[0] if len(t) != 0 else None
    if join_text:
        return ''.join(t).strip()
    else:
        return e.xpath(xpath)
    

def parse_rating_li(e):
    courseName = get_xpath(e, "./div/div[3]/div[1]/div[1]/div/text()", join_text=True)
    date = get_xpath(e, './div/div[3]/div[1]/div[2]/text()', one=True)
    quality = get_xpath(e, './div/div[2]/div[1]/div/div[2]/text()', one=True)
    difficulty = get_xpath(e, './div/div[2]/div[2]/div/div[2]/text()', one=True)
    
    return {
        'courseName': courseName,
        'date': date,
        'quality': quality,
        'difficulty': difficulty
    }

def get_professor_detail(professor_id: str):
    url = "https://www.ratemyprofessors.com/professor/599472"
    res = requests.get(url)
    firstName = root.xpath('//*[@id="root"]/div/div/div[3]/div[2]/div[1]/div[2]/div[1]/span[1]/text()')[0]
    lastName = root.xpath('//*[@id="root"]/div/div/div[3]/div[2]/div[1]/div[2]/div[1]/span[2]/text()')[0]
    rating = root.xpath('//*[@id="root"]/div/div/div[3]/div[2]/div[1]/div[1]/div[1]/div/div[1]/text()')[0]
    takeAgain = root.xpath('//*[@id="root"]/div/div/div[3]/div[2]/div[1]/div[3]/div[1]/div[1]/text()')[0]
    difficulty = root.xpath('//*[@id="root"]/div/div/div[3]/div[2]/div[1]/div[3]/div[2]/div[1]/text()')[0]
    school = root.xpath('//*[@id="root"]/div/div/div[3]/div[2]/div[1]/div[2]/div[2]/a/text()')[0]
    ratings = [parse_rating_li(li) for li in root.xpath('//*[@id="ratingsList"]/li/div[not(@id="ad-controller")]')]
    
    data = {
        'firstName': firstName,
        'lastName': lastName,
        'rating': rating,
        'takeAgain': takeAgain,
        'difficulty': difficulty,
        'school': school,
        'ratings': ratings
    }
    # print(lxml.html.tostring(ratings[0]))
    # print(len(ratings))

    return data

d = get_professor_detail('VGVhY2hlci01OTk0NzI=')
print(d)
# Out:
# {
#     'firstName': 'Susanne',
#     'lastName': 'Werk',
#     'rating': '4.5',
#     'takeAgain': '82%',
#     'difficulty': '3',
#     'school': 'Boston University',
#     'ratings': [
#         {'courseName': 'LG309', 'date': 'May 3rd, 2023', 'quality': '5.0', 'difficulty': '3.0'},
#         {'courseName': 'LG111', 'date': 'Apr 17th, 2023', 'quality': '5.0', 'difficulty': '3.0'},
#         {'courseName': 'LG112', 'date': 'Dec 17th, 2022', 'quality': '5.0', 'difficulty': '3.0'},
#         {'courseName': 'LG111', 'date': 'Dec 14th, 2021', 'quality': '5.0', 'difficulty': '3.0'},
#         {'courseName': 'LG211', 'date': 'Dec 7th, 2021', 'quality': '5.0', 'difficulty': '4.0'},
#         {'courseName': 'LG111', 'date': 'Jan 28th, 2021', 'quality': '4.0', 'difficulty': '4.0'},
#         {'courseName': 'LG211', 'date': 'Oct 18th, 2020', 'quality': '1.0', 'difficulty': '4.0'},
#         {'courseName': 'LG111', 'date': 'Apr 22nd, 2020', 'quality': '3.0', 'difficulty': '3.0'},
# ...
